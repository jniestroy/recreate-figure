# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/Users/justinniestroy-admin/Documents/Work/Randall Data/'

# %%
data = pd.read_csv(path + 'moss_plos_one_data.csv')

# %%
from io import StringIO
fig_df = data.iloc[:,[17,20,47,52]]
s = StringIO()
fig_df.to_csv(s)
s

# %%
s.get_value()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-155-0fef43cc4d5a> in <module>
# ----> 1 s.get_value()
#
# AttributeError: '_io.StringIO' object has no attribute 'get_value'

# %%
fig_df = data.iloc[:,[17,20,47,52]]

# %%
bins = np.linspace(30, 150, 100)

pyplot.hist(fig_df['Pulse'], bins, alpha=0.5, label='Charted VS')
pyplot.hist(fig_df['hr'], bins, alpha=0.5, label='ECG VS',color = "red")
pyplot.legend(loc='upper right')
pyplot.title('Heart Rate')
pyplot.ylabel('Count')
pyplot.show()

# %%
bins = np.linspace(10, 40, 50)

pyplot.hist(fig_df['Resp'], bins, alpha=0.5, label='Charted VS')
pyplot.hist(fig_df['edrk'], bins, alpha=0.5, label='ECG VS',color = "red")
pyplot.legend(loc='upper right')
pyplot.title('Respitory Rate')
pyplot.show()

# %%
import seaborn as sns
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv')
x1 = df.loc[df.cut=='Ideal', ['depth']]
x2 = df.loc[df.cut=='Fair', ['depth']]
x3 = df.loc[df.cut=='Good', ['depth']]

# plot
fig, axes = plt.subplots(1, 2, figsize=(10, 3), sharey=True, dpi=100)
sns.distplot(fig_df['Pulse'] , color="skyblue",bins=300, ax=axes[0],kde=False).set_title('Heart Rate')
sns.distplot(fig_df['hr'] , color="red", bins=300,ax=axes[0],kde=False,axlabel='Beats/Min')
axes[0].set_xlim(30,160);
axes[0].set_ylim(0,150000)
sns.distplot(fig_df['Resp'] , color="skyblue", ax=axes[1],kde=False).set_title('Resp Rate')
sns.distplot(fig_df['edrk'] , color="red", ax=axes[1],kde=False,axlabel='Breaths/Min')
axes[1].set_ylim(0,100000)
plt.xlim(5,40);

# %%
import matplotlib.pyplot as plt


ax1 = plt.subplot(131)
ax1.hist(fig_df['Pulse'], np.linspace(30, 150, 100), alpha=0.5, label='Charted VS')
ax1.hist(fig_df['hr'], np.linspace(30, 150, 100), alpha=0.5, label='ECG',color = "red")
ax1.set_title('Heart Rate')
ax1.set_xlabel("Beats/Min")
ax1.set_ylabel('Count')
ax1.set_xlim([30, 150])


ax2 = plt.subplot(132)
ax2.hist(fig_df['Resp'], np.linspace(10, 40, 35), alpha=0.5, label='Charted VS')
ax2.hist(fig_df['edrk'], np.linspace(10, 40, 35), alpha=0.5, label='ECG',color = "red")
ax2.set_xlabel('Breaths/Min')
ax2.set_title('Resp Rate')
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.subplots_adjust(left=None, bottom=None, right=3, top=None, wspace=None, hspace=None)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

clean = "clean.csv"
fig_df = pd.read_csv(clean)



ax1 = plt.subplot(131)
ax1.hist(fig_df['Pulse'], np.linspace(30, 150, 100), alpha=0.5, label='Charted VS')
ax1.hist(fig_df['hr'], np.linspace(30, 150, 100), alpha=0.5, label='ECG',color = "red")
ax1.set_title('Heart Rate')
ax1.set_xlabel("Beats/Min")
ax1.set_ylabel('Count')
ax1.set_xlim([30, 150])


ax2 = plt.subplot(132)
ax2.hist(fig_df['Resp'], np.linspace(10, 40, 35), alpha=0.5, label='Charted VS')
ax2.hist(fig_df['edrk'], np.linspace(10, 40, 35), alpha=0.5, label='ECG',color = "red")
ax2.set_xlabel('Breaths/Min')
ax2.set_title('Resp Rate')
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.subplots_adjust(left=None, bottom=None, right=3, top=None, wspace=None, hspace=None)

plt.savefig('test.png', bbox_inches='tight')

plt.show()

# %%
import os
os.listdir()
# Out:
# ['fig.yaml',
#  '.DS_Store',
#  'requirements.txt',
#  'clean.csv',
#  'Dockerfile',
#  'data_cleaning.py',
#  'make_fig.cwl',
#  'data cleaning script.ipynb',
#  '.ipynb_checkpoints',
#  'create_fig.cwl',
#  'create_fig.py',
#  'clean_data.cwl',
#  'figure.png']

# %%
# Out:
# 256
